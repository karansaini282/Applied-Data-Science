# %% [markdown]
# # ADS Homework 4
# Wednesday Session, Proffessor Stanislav Sobolevsky
#
# Please submit this assignment to the NYU Classes 'Assignments' section by labeling the assignments with the format **'FULL_NAME - ADS_HW4.ipynb'**.
#
# This homework is here for you to better understand and practice the material; while you may discuss approaches to problems with your classmates (in fact, this is encouraged!), please ensure that all final code submitted is your own. You may reach out to the TAs or Professor Sobolevsky via email or during office hours, in case you have any questions or have some difficulties following the class material.

# %% [markdown]
# ## Problem 1 - Return on University Education (20 points)

# %% [markdown]
# Please read the following article: https://promarket.org/learning-university-pay-off/
#
# Consider Judea Pearl's idea of the ladder of causality that was discussed in class.  Describe whether or not the study described in the article meets the standard of (a) association; (b) intervention; and (c) counterfactual.

# %% [markdown]
# **(a)** The study meets the standard of association. It checks for correlation between skills and quality of students with wages earned.

# %% [markdown]
# **(b)** The study meets the standard of intervention. The change in curriculum resembles a natural experiment to test how an intervention changing skills of students while keeping quality os students the same impacted the wages.

# %% [markdown]
# **(c)** The stdudy doesn't meet the standard of counterfactual. It does not test the hypothesis under circumstances which would have occured differently.

# %% [markdown]
# ## Problem 2 - Markov Processes (40 points)

# %% [markdown]
# ### Part 1 - Markov Chain Lab (20 points)
#
# * Consider the subway rat problem discussed in class.
# * Add two tracks to the right of Track C, labeling them Track D and Track E.
# * In this situation, treat Track A as an absorbing state.
# * If the rat is on any track other than Tracks A or E, it has probability 0.5 of remaining on that track, probability 0.25 of moving left, and probability 0.25 of moving right.
# * For Track E, assume probability 0.5 of remaining on that track, and probability 0.5 of moving left.
#
# * Write out the matrix of Markov transition probabilities.  Iterate this matrix forward as many times as is necessary for you to determine empirically its limit.  Based on this limit, what can you say about the evolution of the system if the rat begins on Track C?  How about Track D?  Is there a general conclusion you can draw?

# %%
# If on Track A, Pr(stays) = 1/2 and Pr(moves to B) = 1/2
# If on Track B, Pr(stays) = 1/2, Pr(move to A) = 1/4, and Pr(moves to C) = 1/4
# If on Track C, Pr(stays) = 1/2, Pr(move to B) = 1/4, and Pr(moves to D) = 1/4
# If on Track D, Pr(stays) = 1/2, Pr(move to C) = 1/4, and Pr(moves to E) = 1/4
# If on Track E, Pr(stays) = 1/2 and Pr(moves to D) = 1/2 

from tabulate import tabulate
import numpy as np

print("A Rat in a NYC Subway Tunnel")
table = [[" ", "Track A", "Track B", "Track C", "Track D", "Track E"],
        ["Track A", "1", "0", "0", "0", "0"],
        ["Track B", "1/4", "1/2", "1/4", "0", "0"],
        ["Track C", "0", "1/4", "1/2", "1/4", "0"],
        ["Track D", "0", "0", "1/4", "1/2", "1/4"],
        ["Track E", "0", "0", "0", "1/2", "1/2"],]
print(tabulate(table, tablefmt="fancy_grid", numalign = "center"))
print()

MT = np.matrix('1 0 0 0 0; 0.25 0.5 0.25 0 0; 0 0.25 0.5 0.25 0; 0 0 0.25 0.5 0.25; 0 0 0 0.5 0.5')
print("As an Numpy matrix")
print(MT)
# Out:
# A Rat in a NYC Subway Tunnel
# ╒═════════╤═════════╤═════════╤═════════╤═════════╤═════════╕
# │         │ Track A │ Track B │ Track C │ Track D │ Track E │
# ├─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ Track A │ 1       │ 0       │ 0       │ 0       │ 0       │
# ├─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ Track B │ 1/4     │ 1/2     │ 1/4     │ 0       │ 0       │
# ├─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ Track C │ 0       │ 1/4     │ 1/2     │ 1/4     │ 0       │
# ├─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ Track D │ 0       │ 0       │ 1/4     │ 1/2     │ 1/4     │
# ├─────────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ Track E │ 0       │ 0       │ 0       │ 1/2     │ 1/2     │
# ╘═════════╧═════════╧═════════╧═════════╧═════════╧═════════╛
#
# As an Numpy matrix
# [[ 1.    0.    0.    0.    0.  ]
#  [ 0.25  0.5   0.25  0.    0.  ]
#  [ 0.    0.25  0.5   0.25  0.  ]
#  [ 0.    0.    0.25  0.5   0.25]
#  [ 0.    0.    0.    0.5   0.5 ]]

# %%
print()
print("Let the rat start at track C")
print()
rat = np.matrix('0 0 1 0 0') #start at C
for i in range(1, 175):
    print('Probability rat in on Track A, B, C, D or E at time t + %i' % (i))
    print(rat * np.linalg.matrix_power(MT, i))
    print()
# Out:
# Let the rat start at track C
#
# Probability rat in on Track A, B, C, D or E at time t + 1
# [[ 0.    0.25  0.5   0.25  0.  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 2
# [[ 0.0625  0.25    0.375   0.25    0.0625]]
#
# Probability rat in on Track A, B, C, D or E at time t + 3
# [[ 0.125    0.21875  0.3125   0.25     0.09375]]
#
# Probability rat in on Track A, B, C, D or E at time t + 4
# [[ 0.1796875  0.1875     0.2734375  0.25       0.109375 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 5
# [[ 0.2265625   0.16210938  0.24609375  0.24804688  0.1171875 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 6
# [[ 0.26708984  0.14257812  0.22558594  0.24414062  0.12060547]]
#
# Probability rat in on Track A, B, C, D or E at time t + 7
# [[ 0.30273438  0.12768555  0.20947266  0.23876953  0.12133789]]
#
# Probability rat in on Track A, B, C, D or E at time t + 8
# [[ 0.33465576  0.11621094  0.1963501   0.23242188  0.12036133]]
#
# Probability rat in on Track A, B, C, D or E at time t + 9
# [[ 0.3637085   0.10719299  0.18533325  0.22547913  0.11828613]]
#
# Probability rat in on Track A, B, C, D or E at time t + 10
# [[ 0.39050674  0.09992981  0.17583466  0.21821594  0.11551285]]
#
# Probability rat in on Track A, B, C, D or E at time t + 11
# [[ 0.4154892   0.09392357  0.16745377  0.21082306  0.11231041]]
#
# Probability rat in on Track A, B, C, D or E at time t + 12
# [[ 0.43897009  0.08882523  0.15991354  0.20343018  0.10886097]]
#
# Probability rat in on Track A, B, C, D or E at time t + 13
# [[ 0.4611764   0.084391    0.15302062  0.19612396  0.10528803]]
#
# Probability rat in on Track A, B, C, D or E at time t + 14
# [[ 0.48227414  0.08045065  0.14663905  0.18896115  0.101675  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 15
# [[ 0.50238681  0.07688509  0.14067248  0.18197784  0.09807779]]
#
# Probability rat in on Track A, B, C, D or E at time t + 16
# [[ 0.52160808  0.07361066  0.13505197  0.17519593  0.09453335]]
#
# Probability rat in on Track A, B, C, D or E at time t + 17
# [[ 0.54001075  0.07056832  0.12972763  0.16862764  0.09106566]]
#
# Probability rat in on Track A, B, C, D or E at time t + 18
# [[ 0.55765283  0.06771607  0.12466281  0.16227856  0.08768974]]
#
# Probability rat in on Track A, B, C, D or E at time t + 19
# [[ 0.57458185  0.06502374  0.11983006  0.15614985  0.08441451]]
#
# Probability rat in on Track A, B, C, D or E at time t + 20
# [[ 0.59083778  0.06246938  0.11520843  0.15023969  0.08124472]]
#
# Probability rat in on Track A, B, C, D or E at time t + 21
# [[ 0.60645513  0.0600368   0.11078148  0.14454431  0.07818228]]
#
# Probability rat in on Track A, B, C, D or E at time t + 22
# [[ 0.62146432  0.05771377  0.10653602  0.13905867  0.07522722]]
#
# Probability rat in on Track A, B, C, D or E at time t + 23
# [[ 0.63589277  0.05549089  0.10246112  0.13377695  0.07237828]]
#
# Probability rat in on Track A, B, C, D or E at time t + 24
# [[ 0.64976549  0.05336072  0.09854752  0.12869289  0.06963338]]
#
# Probability rat in on Track A, B, C, D or E at time t + 25
# [[ 0.66310567  0.05131724  0.09478716  0.12380001  0.06698991]]
#
# Probability rat in on Track A, B, C, D or E at time t + 26
# [[ 0.67593498  0.04935541  0.0911729   0.11909175  0.06444496]]
#
# Probability rat in on Track A, B, C, D or E at time t + 27
# [[ 0.68827383  0.04747093  0.08769824  0.11456158  0.06199542]]
#
# Probability rat in on Track A, B, C, D or E at time t + 28
# [[ 0.70014157  0.04566002  0.08435725  0.11020306  0.0596381 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 29
# [[ 0.71155657  0.04391932  0.08114439  0.10600989  0.05736982]]
#
# Probability rat in on Track A, B, C, D or E at time t + 30
# [[ 0.7225364   0.04224576  0.0780545   0.10197595  0.05518738]]
#
# Probability rat in on Track A, B, C, D or E at time t + 31
# [[ 0.73309784  0.04063651  0.07508268  0.09809529  0.05308768]]
#
# Probability rat in on Track A, B, C, D or E at time t + 32
# [[ 0.74325697  0.03908892  0.07222429  0.09436216  0.05106766]]
#
# Probability rat in on Track A, B, C, D or E at time t + 33
# [[ 0.7530292   0.03760053  0.06947491  0.09077098  0.04912437]]
#
# Probability rat in on Track A, B, C, D or E at time t + 34
# [[ 0.76242933  0.036169    0.06683034  0.0873164   0.04725493]]
#
# Probability rat in on Track A, B, C, D or E at time t + 35
# [[ 0.77147158  0.03479208  0.06428652  0.08399325  0.04545657]]
#
# Probability rat in on Track A, B, C, D or E at time t + 36
# [[ 0.7801696   0.03346767  0.06183959  0.08079654  0.0437266 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 37
# [[ 0.78853652  0.03219373  0.05948585  0.07772147  0.04206243]]
#
# Probability rat in on Track A, B, C, D or E at time t + 38
# [[ 0.79658495  0.03096833  0.05722172  0.07476341  0.04046158]]
#
# Probability rat in on Track A, B, C, D or E at time t + 39
# [[ 0.80432704  0.0297896   0.0550438   0.07191793  0.03892164]]
#
# Probability rat in on Track A, B, C, D or E at time t + 40
# [[ 0.81177444  0.02865575  0.05294878  0.06918073  0.0374403 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 41
# [[ 0.81893837  0.02756507  0.05093351  0.06654771  0.03601534]]
#
# Probability rat in on Track A, B, C, D or E at time t + 42
# [[ 0.82582964  0.02651591  0.04899495  0.0640149   0.0346446 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 43
# [[ 0.83245862  0.02550669  0.04713018  0.06157849  0.03332602]]
#
# Probability rat in on Track A, B, C, D or E at time t + 44
# [[ 0.83883529  0.02453589  0.04533638  0.0592348   0.03205763]]
#
# Probability rat in on Track A, B, C, D or E at time t + 45
# [[ 0.84496926  0.02360204  0.04361087  0.05698031  0.03083752]]
#
# Probability rat in on Track A, B, C, D or E at time t + 46
# [[ 0.85086977  0.02270374  0.04195102  0.05481163  0.02966384]]
#
# Probability rat in on Track A, B, C, D or E at time t + 47
# [[ 0.85654571  0.02183962  0.04035435  0.05272549  0.02853483]]
#
# Probability rat in on Track A, B, C, D or E at time t + 48
# [[ 0.86200561  0.0210084   0.03881845  0.05071875  0.02744879]]
#
# Probability rat in on Track A, B, C, D or E at time t + 49
# [[ 0.86725771  0.02020881  0.03734101  0.04878838  0.02640408]]
#
# Probability rat in on Track A, B, C, D or E at time t + 50
# [[ 0.87230992  0.01943966  0.03591981  0.04693148  0.02539913]]
#
# Probability rat in on Track A, B, C, D or E at time t + 51
# [[ 0.87716983  0.01869978  0.03455269  0.04514526  0.02443244]]
#
# Probability rat in on Track A, B, C, D or E at time t + 52
# [[ 0.88184478  0.01798806  0.0332376   0.04342702  0.02350253]]
#
# Probability rat in on Track A, B, C, D or E at time t + 53
# [[ 0.88634179  0.01730343  0.03197257  0.04177418  0.02260802]]
#
# Probability rat in on Track A, B, C, D or E at time t + 54
# [[ 0.89066765  0.01664486  0.03075569  0.04018424  0.02174756]]
#
# Probability rat in on Track A, B, C, D or E at time t + 55
# [[ 0.89482887  0.01601135  0.02958512  0.03865482  0.02091984]]
#
# Probability rat in on Track A, B, C, D or E at time t + 56
# [[ 0.8988317   0.01540196  0.0284591   0.03718361  0.02012362]]
#
# Probability rat in on Track A, B, C, D or E at time t + 57
# [[ 0.90268219  0.01481575  0.02737594  0.03576839  0.01935772]]
#
# Probability rat in on Track A, B, C, D or E at time t + 58
# [[ 0.90638613  0.01425186  0.02633401  0.03440704  0.01862096]]
#
# Probability rat in on Track A, B, C, D or E at time t + 59
# [[ 0.9099491   0.01370943  0.02533173  0.0330975   0.01791224]]
#
# Probability rat in on Track A, B, C, D or E at time t + 60
# [[ 0.91337646  0.01318765  0.0243676   0.0318378   0.01723049]]
#
# Probability rat in on Track A, B, C, D or E at time t + 61
# [[ 0.91667337  0.01268572  0.02344016  0.03062605  0.0165747 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 62
# [[ 0.9198448   0.0122029   0.02254802  0.02946041  0.01594386]]
#
# Probability rat in on Track A, B, C, D or E at time t + 63
# [[ 0.92289553  0.01173846  0.02168984  0.02833914  0.01533703]]
#
# Probability rat in on Track A, B, C, D or E at time t + 64
# [[ 0.92583014  0.01129169  0.02086432  0.02726055  0.0147533 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 65
# [[ 0.92865306  0.01086192  0.02007022  0.02622301  0.01419179]]
#
# Probability rat in on Track A, B, C, D or E at time t + 66
# [[ 0.93136854  0.01044852  0.01930634  0.02522495  0.01365165]]
#
# Probability rat in on Track A, B, C, D or E at time t + 67
# [[ 0.93398067  0.01005084  0.01857154  0.02426488  0.01313206]]
#
# Probability rat in on Track A, B, C, D or E at time t + 68
# [[ 0.93649338  0.00966831  0.0178647   0.02334136  0.01263225]]
#
# Probability rat in on Track A, B, C, D or E at time t + 69
# [[ 0.93891046  0.00930033  0.01718477  0.02245298  0.01215146]]
#
# Probability rat in on Track A, B, C, D or E at time t + 70
# [[ 0.94123554  0.00894636  0.01653071  0.02159841  0.01168898]]
#
# Probability rat in on Track A, B, C, D or E at time t + 71
# [[ 0.94347213  0.00860586  0.01590155  0.02077637  0.01124409]]
#
# Probability rat in on Track A, B, C, D or E at time t + 72
# [[ 0.9456236   0.00827831  0.01529633  0.01998562  0.01081614]]
#
# Probability rat in on Track A, B, C, D or E at time t + 73
# [[ 0.94769317  0.00796324  0.01471415  0.01922496  0.01040447]]
#
# Probability rat in on Track A, B, C, D or E at time t + 74
# [[ 0.94968398  0.00766016  0.01415413  0.01849326  0.01000848]]
#
# Probability rat in on Track A, B, C, D or E at time t + 75
# [[ 0.95159902  0.00736861  0.01361542  0.0177894   0.00962755]]
#
# Probability rat in on Track A, B, C, D or E at time t + 76
# [[ 0.95344118  0.00708816  0.01309721  0.01711233  0.00926113]]
#
# Probability rat in on Track A, B, C, D or E at time t + 77
# [[ 0.95521322  0.00681838  0.01259873  0.01646103  0.00890865]]
#
# Probability rat in on Track A, B, C, D or E at time t + 78
# [[ 0.95691781  0.00655887  0.01211922  0.01583452  0.00856958]]
#
# Probability rat in on Track A, B, C, D or E at time t + 79
# [[ 0.95855753  0.00630924  0.01165796  0.01523185  0.00824342]]
#
# Probability rat in on Track A, B, C, D or E at time t + 80
# [[ 0.96013484  0.00606911  0.01121425  0.01465213  0.00792967]]
#
# Probability rat in on Track A, B, C, D or E at time t + 81
# [[ 0.96165212  0.00583812  0.01078743  0.01409446  0.00762787]]
#
# Probability rat in on Track A, B, C, D or E at time t + 82
# [[ 0.96311165  0.00561592  0.01037686  0.01355802  0.00733755]]
#
# Probability rat in on Track A, B, C, D or E at time t + 83
# [[ 0.96451563  0.00540217  0.00998192  0.013042    0.00705828]]
#
# Probability rat in on Track A, B, C, D or E at time t + 84
# [[ 0.96586617  0.00519657  0.009602    0.01254562  0.00678964]]
#
# Probability rat in on Track A, B, C, D or E at time t + 85
# [[ 0.96716531  0.00499878  0.00923655  0.01206813  0.00653123]]
#
# Probability rat in on Track A, B, C, D or E at time t + 86
# [[ 0.96841501  0.00480853  0.008885    0.01160882  0.00628265]]
#
# Probability rat in on Track A, B, C, D or E at time t + 87
# [[ 0.96961714  0.00462552  0.00854684  0.01116698  0.00604353]]
#
# Probability rat in on Track A, B, C, D or E at time t + 88
# [[ 0.97077352  0.00444947  0.00822154  0.01074196  0.00581351]]
#
# Probability rat in on Track A, B, C, D or E at time t + 89
# [[ 0.97188588  0.00428012  0.00790863  0.01033312  0.00559225]]
#
# Probability rat in on Track A, B, C, D or E at time t + 90
# [[ 0.97295591  0.00411722  0.00760762  0.00993984  0.0053794 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 91
# [[ 0.97398522  0.00396051  0.00731808  0.00956153  0.00517466]]
#
# Probability rat in on Track A, B, C, D or E at time t + 92
# [[ 0.97497535  0.00380978  0.00703955  0.00919761  0.00497771]]
#
# Probability rat in on Track A, B, C, D or E at time t + 93
# [[ 0.97592779  0.00366478  0.00677162  0.00884755  0.00478826]]
#
# Probability rat in on Track A, B, C, D or E at time t + 94
# [[ 0.97684399  0.00352529  0.00651389  0.00851081  0.00460602]]
#
# Probability rat in on Track A, B, C, D or E at time t + 95
# [[ 0.97772531  0.00339112  0.00626597  0.00818689  0.00443071]]
#
# Probability rat in on Track A, B, C, D or E at time t + 96
# [[ 0.97857309  0.00326205  0.00602749  0.00787529  0.00426208]]
#
# Probability rat in on Track A, B, C, D or E at time t + 97
# [[ 0.9793886   0.0031379   0.00579808  0.00757556  0.00409986]]
#
# Probability rat in on Track A, B, C, D or E at time t + 98
# [[ 0.98017308  0.00301847  0.0055774   0.00728723  0.00394382]]
#
# Probability rat in on Track A, B, C, D or E at time t + 99
# [[ 0.98092769  0.00290359  0.00536513  0.00700988  0.00379372]]
#
# Probability rat in on Track A, B, C, D or E at time t + 100
# [[ 0.98165359  0.00279307  0.00516093  0.00674308  0.00364933]]
#
# Probability rat in on Track A, B, C, D or E at time t + 101
# [[ 0.98235186  0.00268677  0.0049645   0.00648644  0.00351043]]
#
# Probability rat in on Track A, B, C, D or E at time t + 102
# [[ 0.98302355  0.00258451  0.00477555  0.00623956  0.00337683]]
#
# Probability rat in on Track A, B, C, D or E at time t + 103
# [[ 0.98366968  0.00248614  0.00459379  0.00600208  0.0032483 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 104
# [[ 0.98429121  0.00239152  0.00441895  0.00577364  0.00312467]]
#
# Probability rat in on Track A, B, C, D or E at time t + 105
# [[ 0.98488909  0.0023005   0.00425077  0.00555389  0.00300575]]
#
# Probability rat in on Track A, B, C, D or E at time t + 106
# [[ 0.98546422  0.00221294  0.00408898  0.00534251  0.00289135]]
#
# Probability rat in on Track A, B, C, D or E at time t + 107
# [[ 0.98601745  0.00212872  0.00393335  0.00513917  0.0027813 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 108
# [[ 0.98654963  0.0020477   0.00378365  0.00494358  0.00267544]]
#
# Probability rat in on Track A, B, C, D or E at time t + 109
# [[ 0.98706156  0.00196976  0.00363964  0.00475542  0.00257362]]
#
# Probability rat in on Track A, B, C, D or E at time t + 110
# [[ 0.987554    0.00189479  0.00350112  0.00457443  0.00247566]]
#
# Probability rat in on Track A, B, C, D or E at time t + 111
# [[ 0.9880277   0.00182267  0.00336786  0.00440033  0.00238144]]
#
# Probability rat in on Track A, B, C, D or E at time t + 112
# [[ 0.98848336  0.0017533   0.00323968  0.00423285  0.0022908 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 113
# [[ 0.98892169  0.00168657  0.00311638  0.00407175  0.00220361]]
#
# Probability rat in on Track A, B, C, D or E at time t + 114
# [[ 0.98934333  0.00162238  0.00299777  0.00391677  0.00211974]]
#
# Probability rat in on Track A, B, C, D or E at time t + 115
# [[ 0.98974893  0.00156063  0.00288367  0.0037677   0.00203906]]
#
# Probability rat in on Track A, B, C, D or E at time t + 116
# [[ 0.99013909  0.00150123  0.00277392  0.0036243   0.00196146]]
#
# Probability rat in on Track A, B, C, D or E at time t + 117
# [[ 0.9905144   0.0014441   0.00266834  0.00348636  0.0018868 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 118
# [[ 0.99087542  0.00138913  0.00256679  0.00335367  0.00181499]]
#
# Probability rat in on Track A, B, C, D or E at time t + 119
# [[ 0.9912227   0.00133626  0.00246909  0.00322603  0.00174591]]
#
# Probability rat in on Track A, B, C, D or E at time t + 120
# [[ 0.99155677  0.00128541  0.00237512  0.00310324  0.00167946]]
#
# Probability rat in on Track A, B, C, D or E at time t + 121
# [[ 0.99187812  0.00123648  0.00228472  0.00298513  0.00161554]]
#
# Probability rat in on Track A, B, C, D or E at time t + 122
# [[ 0.99218724  0.00118942  0.00219776  0.00287152  0.00155405]]
#
# Probability rat in on Track A, B, C, D or E at time t + 123
# [[ 0.9924846   0.00114415  0.00211412  0.00276223  0.00149491]]
#
# Probability rat in on Track A, B, C, D or E at time t + 124
# [[ 0.99277063  0.00110061  0.00203365  0.0026571   0.00143801]]
#
# Probability rat in on Track A, B, C, D or E at time t + 125
# [[ 0.99304579  0.00105872  0.00195625  0.00255597  0.00138328]]
#
# Probability rat in on Track A, B, C, D or E at time t + 126
# [[ 0.99331046  0.00101842  0.0018818   0.00245869  0.00133063]]
#
# Probability rat in on Track A, B, C, D or E at time t + 127
# [[  9.93565070e-01   9.79659740e-04   1.81017516e-03   2.36510783e-03
#     1.27998713e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 128
# [[  9.93809985e-01   9.42373661e-04   1.74127947e-03   2.27509127e-03
#     1.23127052e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 129
# [[  9.94045578e-01   9.06506699e-04   1.67500597e-03   2.18850077e-03
#     1.18440808e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 130
# [[  9.94272205e-01   8.72004842e-04   1.61125485e-03   2.10520592e-03
#     1.13932923e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 131
# [[  9.94490206e-01   8.38816134e-04   1.54993012e-03   2.02508129e-03
#     1.09596610e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 132
# [[  9.94699910e-01   8.06890596e-04   1.49093941e-03   1.94800622e-03
#     1.05425337e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 133
# [[  9.94901633e-01   7.76180151e-04   1.43419391e-03   1.87386465e-03
#     1.01412824e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 134
# [[  9.95095678e-01   7.46638553e-04   1.37960816e-03   1.80254492e-03
#     9.75530282e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 135
# [[  9.95282338e-01   7.18221316e-04   1.32709995e-03   1.73393964e-03
#     9.38401371e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 136
# [[  9.95461893e-01   6.90885644e-04   1.27659021e-03   1.66794549e-03
#     9.02685596e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 137
# [[  9.95634614e-01   6.64590375e-04   1.22800289e-03   1.60446310e-03
#     8.68329171e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 138
# [[  9.95800762e-01   6.39295910e-04   1.18126481e-03   1.54339686e-03
#     8.35280360e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 139
# [[  9.95960586e-01   6.14964158e-04   1.13630560e-03   1.48465481e-03
#     8.03489394e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 140
# [[  9.96114327e-01   5.91558479e-04   1.09305754e-03   1.42814850e-03
#     7.72908400e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 141
# [[  9.96262217e-01   5.69043625e-04   1.05145552e-03   1.37379284e-03
#     7.43491326e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 142
# [[  9.96404478e-01   5.47385691e-04   1.01143687e-03   1.32150596e-03
#     7.15193872e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 143
# [[  9.96541324e-01   5.26552064e-04   9.72941350e-04   1.27120913e-03
#     6.87973426e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 144
# [[  9.96672962e-01   5.06511369e-04   9.35910975e-04   1.22282662e-03
#     6.61788997e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 145
# [[  9.96799590e-01   4.87233428e-04   9.00289984e-04   1.17628555e-03
#     6.36601153e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 146
# [[  9.96921398e-01   4.68689210e-04   8.66024737e-04   1.13151585e-03
#     6.12371964e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 147
# [[  9.97038571e-01   4.50850789e-04   8.33063633e-04   1.08845009e-03
#     5.89064944e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 148
# [[  9.97151283e-01   4.33691303e-04   8.01357036e-04   1.04702343e-03
#     5.66644995e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 149
# [[  9.97259706e-01   4.17184911e-04   7.70857200e-04   1.00717347e-03
#     5.45078354e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 150
# [[  9.97364002e-01   4.01306755e-04   7.41518195e-04   9.68840211e-04
#     5.24332544e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 151
# [[  9.97464329e-01   3.86032926e-04   7.13295839e-04   9.31965926e-04
#     5.04376325e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 152
# [[  9.97560837e-01   3.71340423e-04   6.86147633e-04   8.96495085e-04
#     4.85179644e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 153
# [[  9.97653672e-01   3.57207120e-04   6.60032694e-04   8.62374273e-04
#     4.66713593e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 154
# [[  9.97742974e-01   3.43611733e-04   6.34911695e-04   8.29552107e-04
#     4.48950365e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 155
# [[  9.97828877e-01   3.30533790e-04   6.10746807e-04   7.97979159e-04
#     4.31863209e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 156
# [[  9.97911510e-01   3.17953597e-04   5.87501641e-04   7.67607886e-04
#     4.15426394e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 157
# [[  9.97990999e-01   3.05852209e-04   5.65141191e-04   7.38392551e-04
#     3.99615169e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 158
# [[  9.98067462e-01   2.94211402e-04   5.43631786e-04   7.10289157e-04
#     3.84405722e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 159
# [[  9.98141015e-01   2.83013647e-04   5.22941033e-04   6.83255386e-04
#     3.69775150e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 160
# [[  9.98211768e-01   2.72242082e-04   5.03037775e-04   6.57250526e-04
#     3.55701422e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 161
# [[  9.98279829e-01   2.61880485e-04   4.83892039e-04   6.32235418e-04
#     3.42163342e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 162
# [[  9.98345299e-01   2.51913252e-04   4.65474995e-04   6.08172390e-04
#     3.29140526e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 163
# [[  9.98408277e-01   2.42325375e-04   4.47758908e-04   5.85025207e-04
#     3.16613360e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 164
# [[  9.98468858e-01   2.33102415e-04   4.30717100e-04   5.62759011e-04
#     3.04562982e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 165
# [[  9.98527134e-01   2.24230482e-04   4.14323906e-04   5.41340271e-04
#     2.92971244e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 166
# [[  9.98583192e-01   2.15696218e-04   3.98554641e-04   5.20736734e-04
#     2.81820690e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 167
# [[  9.98637116e-01   2.07486769e-04   3.83385559e-04   5.00917372e-04
#     2.71094528e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 168
# [[  9.98688987e-01   1.99589774e-04   3.68793815e-04   4.81852340e-04
#     2.60776607e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 169
# [[  9.98738885e-01   1.91993341e-04   3.54757436e-04   4.63512927e-04
#     2.50851388e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 170
# [[  9.98786883e-01   1.84686029e-04   3.41255285e-04   4.45871517e-04
#     2.41303926e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 171
# [[  9.98833055e-01   1.77656836e-04   3.28267029e-04   4.28901543e-04
#     2.32119842e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 172
# [[  9.98877469e-01   1.70895175e-04   3.15773109e-04   4.12577450e-04
#     2.23285307e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 173
# [[  9.98920193e-01   1.64390865e-04   3.03754711e-04   3.96874655e-04
#     2.14787016e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 174
# [[  9.98961290e-01   1.58134110e-04   2.92193735e-04   3.81769513e-04
#     2.06612172e-04]]

# %%
print()
print("Let the rat start at track D")
print()
rat = np.matrix('0 0 0 1 0') #start at C
for i in range(1, 175):
    print('Probability rat in on Track A, B, C, D or E at time t + %i' % (i))
    print(rat * np.linalg.matrix_power(MT, i))
    print()
# Out:
# Let the rat start at track D
#
# Probability rat in on Track A, B, C, D or E at time t + 1
# [[ 0.    0.    0.25  0.5   0.25]]
#
# Probability rat in on Track A, B, C, D or E at time t + 2
# [[ 0.      0.0625  0.25    0.4375  0.25  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 3
# [[ 0.015625  0.09375   0.25      0.40625   0.234375]]
#
# Probability rat in on Track A, B, C, D or E at time t + 4
# [[ 0.0390625  0.109375   0.25       0.3828125  0.21875  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 5
# [[ 0.06640625  0.1171875   0.24804688  0.36328125  0.20507812]]
#
# Probability rat in on Track A, B, C, D or E at time t + 6
# [[ 0.09570312  0.12060547  0.24414062  0.34619141  0.19335938]]
#
# Probability rat in on Track A, B, C, D or E at time t + 7
# [[ 0.12585449  0.12133789  0.23876953  0.33081055  0.18322754]]
#
# Probability rat in on Track A, B, C, D or E at time t + 8
# [[ 0.15618896  0.12036133  0.23242188  0.31671143  0.17431641]]
#
# Probability rat in on Track A, B, C, D or E at time t + 9
# [[ 0.1862793   0.11828613  0.22547913  0.30361938  0.16633606]]
#
# Probability rat in on Track A, B, C, D or E at time t + 10
# [[ 0.21585083  0.11551285  0.21821594  0.2913475   0.15907288]]
#
# Probability rat in on Track A, B, C, D or E at time t + 11
# [[ 0.24472904  0.11231041  0.21082306  0.27976418  0.15237331]]
#
# Probability rat in on Track A, B, C, D or E at time t + 12
# [[ 0.27280664  0.10886097  0.20343018  0.26877451  0.1461277 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 13
# [[ 0.30002189  0.10528803  0.19612396  0.25830865  0.14025748]]
#
# Probability rat in on Track A, B, C, D or E at time t + 14
# [[ 0.32634389  0.101675    0.18896115  0.24831405  0.1347059 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 15
# [[ 0.35176264  0.09807779  0.18197784  0.23875026  0.12943146]]
#
# Probability rat in on Track A, B, C, D or E at time t + 16
# [[ 0.37628209  0.09453335  0.17519593  0.22958532  0.1244033 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 17
# [[ 0.39991543  0.09106566  0.16862764  0.22079329  0.11959798]]
#
# Probability rat in on Track A, B, C, D or E at time t + 18
# [[ 0.42268185  0.08768974  0.16227856  0.21235255  0.11499731]]
#
# Probability rat in on Track A, B, C, D or E at time t + 19
# [[ 0.44460428  0.08441451  0.15614985  0.20424457  0.11058679]]
#
# Probability rat in on Track A, B, C, D or E at time t + 20
# [[ 0.46570791  0.08124472  0.15023969  0.19645314  0.10635454]]
#
# Probability rat in on Track A, B, C, D or E at time t + 21
# [[ 0.48601909  0.07818228  0.14454431  0.18896376  0.10229056]]
#
# Probability rat in on Track A, B, C, D or E at time t + 22
# [[ 0.50556466  0.07522722  0.13905867  0.18176324  0.09838622]]
#
# Probability rat in on Track A, B, C, D or E at time t + 23
# [[ 0.52437146  0.07237828  0.13377695  0.1748394   0.09463392]]
#
# Probability rat in on Track A, B, C, D or E at time t + 24
# [[ 0.54246603  0.06963338  0.12869289  0.16818089  0.09102681]]
#
# Probability rat in on Track A, B, C, D or E at time t + 25
# [[ 0.55987437  0.06698991  0.12380001  0.16177707  0.08755863]]
#
# Probability rat in on Track A, B, C, D or E at time t + 26
# [[ 0.57662185  0.06444496  0.11909175  0.15561785  0.08422358]]
#
# Probability rat in on Track A, B, C, D or E at time t + 27
# [[ 0.59273309  0.06199542  0.11456158  0.14969366  0.08101625]]
#
# Probability rat in on Track A, B, C, D or E at time t + 28
# [[ 0.60823195  0.0596381   0.11020306  0.14399535  0.07793154]]
#
# Probability rat in on Track A, B, C, D or E at time t + 29
# [[ 0.62314147  0.05736982  0.10600989  0.13851421  0.07496461]]
#
# Probability rat in on Track A, B, C, D or E at time t + 30
# [[ 0.63748393  0.05518738  0.10197595  0.13324188  0.07211086]]
#
# Probability rat in on Track A, B, C, D or E at time t + 31
# [[ 0.65128077  0.05308768  0.09809529  0.12817036  0.0693659 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 32
# [[ 0.66455269  0.05106766  0.09436216  0.12329195  0.06672554]]
#
# Probability rat in on Track A, B, C, D or E at time t + 33
# [[ 0.67731961  0.04912437  0.09077098  0.11859928  0.06418576]]
#
# Probability rat in on Track A, B, C, D or E at time t + 34
# [[ 0.6896007   0.04725493  0.0873164   0.11408527  0.0617427 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 35
# [[ 0.70141443  0.04545657  0.08399325  0.10974308  0.05939267]]
#
# Probability rat in on Track A, B, C, D or E at time t + 36
# [[ 0.71277857  0.0437266   0.08079654  0.10556619  0.0571321 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 37
# [[ 0.72371022  0.04206243  0.07772147  0.10154828  0.0549576 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 38
# [[ 0.73422583  0.04046158  0.07476341  0.09768331  0.05286587]]
#
# Probability rat in on Track A, B, C, D or E at time t + 39
# [[ 0.74434123  0.03892164  0.07191793  0.09396544  0.05085376]]
#
# Probability rat in on Track A, B, C, D or E at time t + 40
# [[ 0.75407164  0.0374403   0.06918073  0.09038908  0.04891824]]
#
# Probability rat in on Track A, B, C, D or E at time t + 41
# [[ 0.76343171  0.03601534  0.06654771  0.08694885  0.04705639]]
#
# Probability rat in on Track A, B, C, D or E at time t + 42
# [[ 0.77243555  0.0346446   0.0640149   0.08363955  0.04526541]]
#
# Probability rat in on Track A, B, C, D or E at time t + 43
# [[ 0.7810967   0.03332602  0.06157849  0.0804562   0.04354259]]
#
# Probability rat in on Track A, B, C, D or E at time t + 44
# [[ 0.7894282   0.03205763  0.0592348   0.07739402  0.04188535]]
#
# Probability rat in on Track A, B, C, D or E at time t + 45
# [[ 0.79744261  0.03083752  0.05698031  0.07444838  0.04029118]]
#
# Probability rat in on Track A, B, C, D or E at time t + 46
# [[ 0.80515199  0.02966384  0.05481163  0.07161486  0.03875768]]
#
# Probability rat in on Track A, B, C, D or E at time t + 47
# [[ 0.81256795  0.02853483  0.05272549  0.06888918  0.03728256]]
#
# Probability rat in on Track A, B, C, D or E at time t + 48
# [[ 0.81970166  0.02744879  0.05071875  0.06626724  0.03586357]]
#
# Probability rat in on Track A, B, C, D or E at time t + 49
# [[ 0.82656385  0.02640408  0.04878838  0.06374509  0.0344986 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 50
# [[ 0.83316487  0.02539913  0.04693148  0.06131894  0.03318557]]
#
# Probability rat in on Track A, B, C, D or E at time t + 51
# [[ 0.83951466  0.02443244  0.04514526  0.05898513  0.03192252]]
#
# Probability rat in on Track A, B, C, D or E at time t + 52
# [[ 0.84562276  0.02350253  0.04342702  0.05674014  0.03070754]]
#
# Probability rat in on Track A, B, C, D or E at time t + 53
# [[ 0.8514984   0.02260802  0.04177418  0.0545806   0.02953881]]
#
# Probability rat in on Track A, B, C, D or E at time t + 54
# [[ 0.8571504   0.02174756  0.04018424  0.05250325  0.02841455]]
#
# Probability rat in on Track A, B, C, D or E at time t + 55
# [[ 0.86258729  0.02091984  0.03865482  0.05050496  0.02733309]]
#
# Probability rat in on Track A, B, C, D or E at time t + 56
# [[ 0.86781725  0.02012362  0.03718361  0.04858273  0.02629278]]
#
# Probability rat in on Track A, B, C, D or E at time t + 57
# [[ 0.87284816  0.01935772  0.03576839  0.04673366  0.02529207]]
#
# Probability rat in on Track A, B, C, D or E at time t + 58
# [[ 0.87768759  0.01862096  0.03440704  0.04495496  0.02432945]]
#
# Probability rat in on Track A, B, C, D or E at time t + 59
# [[ 0.88234283  0.01791224  0.0330975   0.04324397  0.02340347]]
#
# Probability rat in on Track A, B, C, D or E at time t + 60
# [[ 0.88682089  0.01723049  0.0318378   0.04159809  0.02251273]]
#
# Probability rat in on Track A, B, C, D or E at time t + 61
# [[ 0.89112851  0.0165747   0.03062605  0.04001486  0.02165589]]
#
# Probability rat in on Track A, B, C, D or E at time t + 62
# [[ 0.89527218  0.01594386  0.02946041  0.03849188  0.02083166]]
#
# Probability rat in on Track A, B, C, D or E at time t + 63
# [[ 0.89925815  0.01533703  0.02833914  0.03702687  0.0200388 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 64
# [[ 0.90309241  0.0147533   0.02726055  0.03561762  0.01927612]]
#
# Probability rat in on Track A, B, C, D or E at time t + 65
# [[ 0.90678073  0.01419179  0.02622301  0.03426201  0.01854247]]
#
# Probability rat in on Track A, B, C, D or E at time t + 66
# [[ 0.91032868  0.01365165  0.02522495  0.03295799  0.01783673]]
#
# Probability rat in on Track A, B, C, D or E at time t + 67
# [[ 0.91374159  0.01313206  0.02426488  0.0317036   0.01715786]]
#
# Probability rat in on Track A, B, C, D or E at time t + 68
# [[ 0.91702461  0.01263225  0.02334136  0.03049695  0.01650483]]
#
# Probability rat in on Track A, B, C, D or E at time t + 69
# [[ 0.92018267  0.01215146  0.02245298  0.02933623  0.01587665]]
#
# Probability rat in on Track A, B, C, D or E at time t + 70
# [[ 0.92322054  0.01168898  0.02159841  0.02821969  0.01527238]]
#
# Probability rat in on Track A, B, C, D or E at time t + 71
# [[ 0.92614278  0.01124409  0.02077637  0.02714564  0.01469111]]
#
# Probability rat in on Track A, B, C, D or E at time t + 72
# [[ 0.9289538   0.01081614  0.01998562  0.02611247  0.01413197]]
#
# Probability rat in on Track A, B, C, D or E at time t + 73
# [[ 0.93165784  0.01040447  0.01922496  0.02511862  0.0135941 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 74
# [[ 0.93425896  0.01000848  0.01849326  0.0241626   0.01307671]]
#
# Probability rat in on Track A, B, C, D or E at time t + 75
# [[ 0.93676108  0.00962755  0.0177894   0.02324297  0.012579  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 76
# [[ 0.93916796  0.00926113  0.01711233  0.02235834  0.01210024]]
#
# Probability rat in on Track A, B, C, D or E at time t + 77
# [[ 0.94148325  0.00890865  0.01646103  0.02150737  0.01163971]]
#
# Probability rat in on Track A, B, C, D or E at time t + 78
# [[ 0.94371041  0.00856958  0.01583452  0.0206888   0.0111967 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 79
# [[ 0.9458528   0.00824342  0.01523185  0.01990138  0.01077055]]
#
# Probability rat in on Track A, B, C, D or E at time t + 80
# [[ 0.94791366  0.00792967  0.01465213  0.01914393  0.01036062]]
#
# Probability rat in on Track A, B, C, D or E at time t + 81
# [[ 0.94989608  0.00762787  0.01409446  0.0184153   0.00996629]]
#
# Probability rat in on Track A, B, C, D or E at time t + 82
# [[ 0.95180304  0.00733755  0.01355802  0.01771441  0.00958697]]
#
# Probability rat in on Track A, B, C, D or E at time t + 83
# [[ 0.95363743  0.00705828  0.013042    0.0170402   0.00922209]]
#
# Probability rat in on Track A, B, C, D or E at time t + 84
# [[ 0.955402    0.00678964  0.01254562  0.01639164  0.00887109]]
#
# Probability rat in on Track A, B, C, D or E at time t + 85
# [[ 0.95709941  0.00653123  0.01206813  0.01576777  0.00853346]]
#
# Probability rat in on Track A, B, C, D or E at time t + 86
# [[ 0.95873222  0.00628265  0.01160882  0.01516765  0.00820867]]
#
# Probability rat in on Track A, B, C, D or E at time t + 87
# [[ 0.96030288  0.00604353  0.01116698  0.01459036  0.00789625]]
#
# Probability rat in on Track A, B, C, D or E at time t + 88
# [[ 0.96181376  0.00581351  0.01074196  0.01403505  0.00759572]]
#
# Probability rat in on Track A, B, C, D or E at time t + 89
# [[ 0.96326714  0.00559225  0.01033312  0.01350087  0.00730662]]
#
# Probability rat in on Track A, B, C, D or E at time t + 90
# [[ 0.9646652   0.0053794   0.00993984  0.01298703  0.00702853]]
#
# Probability rat in on Track A, B, C, D or E at time t + 91
# [[ 0.96601005  0.00517466  0.00956153  0.01249274  0.00676102]]
#
# Probability rat in on Track A, B, C, D or E at time t + 92
# [[ 0.96730372  0.00497771  0.00919761  0.01201726  0.0065037 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 93
# [[ 0.96854814  0.00478826  0.00884755  0.01155988  0.00625616]]
#
# Probability rat in on Track A, B, C, D or E at time t + 94
# [[ 0.96974521  0.00460602  0.00851081  0.01111991  0.00601805]]
#
# Probability rat in on Track A, B, C, D or E at time t + 95
# [[ 0.97089671  0.00443071  0.00818689  0.01069668  0.005789  ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 96
# [[ 0.97200439  0.00426208  0.00787529  0.01028957  0.00556867]]
#
# Probability rat in on Track A, B, C, D or E at time t + 97
# [[ 0.97306991  0.00409986  0.00757556  0.00989794  0.00535673]]
#
# Probability rat in on Track A, B, C, D or E at time t + 98
# [[ 0.97409488  0.00394382  0.00728723  0.00952122  0.00515285]]
#
# Probability rat in on Track A, B, C, D or E at time t + 99
# [[ 0.97508083  0.00379372  0.00700988  0.00915884  0.00495673]]
#
# Probability rat in on Track A, B, C, D or E at time t + 100
# [[ 0.97602926  0.00364933  0.00674308  0.00881026  0.00476808]]
#
# Probability rat in on Track A, B, C, D or E at time t + 101
# [[ 0.97694159  0.00351043  0.00648644  0.00847494  0.0045866 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 102
# [[ 0.9778192   0.00337683  0.00623956  0.00815238  0.00441204]]
#
# Probability rat in on Track A, B, C, D or E at time t + 103
# [[ 0.97866341  0.0032483   0.00600208  0.0078421   0.00424411]]
#
# Probability rat in on Track A, B, C, D or E at time t + 104
# [[ 0.97947548  0.00312467  0.00577364  0.00754362  0.00408258]]
#
# Probability rat in on Track A, B, C, D or E at time t + 105
# [[ 0.98025665  0.00300575  0.00555389  0.00725651  0.0039272 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 106
# [[ 0.98100809  0.00289135  0.00534251  0.00698033  0.00377773]]
#
# Probability rat in on Track A, B, C, D or E at time t + 107
# [[ 0.98173092  0.0027813   0.00513917  0.00671466  0.00363395]]
#
# Probability rat in on Track A, B, C, D or E at time t + 108
# [[ 0.98242625  0.00267544  0.00494358  0.00645909  0.00349564]]
#
# Probability rat in on Track A, B, C, D or E at time t + 109
# [[ 0.98309511  0.00257362  0.00475542  0.00621326  0.00336259]]
#
# Probability rat in on Track A, B, C, D or E at time t + 110
# [[ 0.98373851  0.00247566  0.00457443  0.00597678  0.00323461]]
#
# Probability rat in on Track A, B, C, D or E at time t + 111
# [[ 0.98435743  0.00238144  0.00440033  0.0057493   0.0031115 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 112
# [[ 0.98495279  0.0022908   0.00423285  0.00553048  0.00299308]]
#
# Probability rat in on Track A, B, C, D or E at time t + 113
# [[ 0.98552549  0.00220361  0.00407175  0.00531999  0.00287916]]
#
# Probability rat in on Track A, B, C, D or E at time t + 114
# [[ 0.98607639  0.00211974  0.00391677  0.00511751  0.00276958]]
#
# Probability rat in on Track A, B, C, D or E at time t + 115
# [[ 0.98660633  0.00203906  0.0037677   0.00492274  0.00266417]]
#
# Probability rat in on Track A, B, C, D or E at time t + 116
# [[ 0.9871161   0.00196146  0.0036243   0.00473538  0.00256277]]
#
# Probability rat in on Track A, B, C, D or E at time t + 117
# [[ 0.98760646  0.0018868   0.00348636  0.00455515  0.00246523]]
#
# Probability rat in on Track A, B, C, D or E at time t + 118
# [[ 0.98807816  0.00181499  0.00335367  0.00438178  0.0023714 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 119
# [[ 0.98853191  0.00174591  0.00322603  0.00421501  0.00228115]]
#
# Probability rat in on Track A, B, C, D or E at time t + 120
# [[ 0.98896839  0.00167946  0.00310324  0.00405458  0.00219432]]
#
# Probability rat in on Track A, B, C, D or E at time t + 121
# [[ 0.98938825  0.00161554  0.00298513  0.00390026  0.00211081]]
#
# Probability rat in on Track A, B, C, D or E at time t + 122
# [[ 0.98979214  0.00155405  0.00287152  0.00375182  0.00203047]]
#
# Probability rat in on Track A, B, C, D or E at time t + 123
# [[ 0.99018065  0.00149491  0.00276223  0.00360902  0.00195319]]
#
# Probability rat in on Track A, B, C, D or E at time t + 124
# [[ 0.99055438  0.00143801  0.0026571   0.00347166  0.00187885]]
#
# Probability rat in on Track A, B, C, D or E at time t + 125
# [[ 0.99091388  0.00138328  0.00255597  0.00333953  0.00180734]]
#
# Probability rat in on Track A, B, C, D or E at time t + 126
# [[ 0.9912597   0.00133063  0.00245869  0.00321243  0.00173855]]
#
# Probability rat in on Track A, B, C, D or E at time t + 127
# [[ 0.99159236  0.00127999  0.00236511  0.00309016  0.00167238]]
#
# Probability rat in on Track A, B, C, D or E at time t + 128
# [[ 0.99191236  0.00123127  0.00227509  0.00297255  0.00160873]]
#
# Probability rat in on Track A, B, C, D or E at time t + 129
# [[ 0.99222017  0.00118441  0.0021885   0.00285941  0.0015475 ]]
#
# Probability rat in on Track A, B, C, D or E at time t + 130
# [[ 0.99251628  0.00113933  0.00210521  0.00275058  0.00148861]]
#
# Probability rat in on Track A, B, C, D or E at time t + 131
# [[ 0.99280111  0.00109597  0.00202508  0.0026459   0.00143195]]
#
# Probability rat in on Track A, B, C, D or E at time t + 132
# [[ 0.9930751   0.00105425  0.00194801  0.00254519  0.00137745]]
#
# Probability rat in on Track A, B, C, D or E at time t + 133
# [[ 0.99333866  0.00101413  0.00187386  0.00244832  0.00132502]]
#
# Probability rat in on Track A, B, C, D or E at time t + 134
# [[  9.93592195e-01   9.75530282e-04   1.80254492e-03   2.35513844e-03
#     1.27459174e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 135
# [[  9.93836077e-01   9.38401371e-04   1.73393964e-03   2.26550132e-03
#     1.22608048e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 136
# [[  9.94070678e-01   9.02685596e-04   1.66794549e-03   2.17927581e-03
#     1.17941557e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 137
# [[  9.94296349e-01   8.68329171e-04   1.60446310e-03   2.09633206e-03
#     1.13452674e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 138
# [[  9.94513431e-01   8.35280360e-04   1.54339686e-03   2.01654517e-03
#     1.09134638e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 139
# [[  9.94722251e-01   8.03489394e-04   1.48465481e-03   1.93979499e-03
#     1.04980949e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 140
# [[  9.94923124e-01   7.72908400e-04   1.42814850e-03   1.86596594e-03
#     1.00985349e-03]]
#
# Probability rat in on Track A, B, C, D or E at time t + 141
# [[  9.95116351e-01   7.43491326e-04   1.37379284e-03   1.79494684e-03
#     9.71418231e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 142
# [[  9.95302224e-01   7.15193872e-04   1.32150596e-03   1.72663075e-03
#     9.34445826e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 143
# [[  9.95481022e-01   6.87973426e-04   1.27120913e-03   1.66091478e-03
#     8.98880599e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 144
# [[  9.95653015e-01   6.61788997e-04   1.22282662e-03   1.59769997e-03
#     8.64668994e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 145
# [[  9.95818463e-01   6.36601153e-04   1.17628555e-03   1.53689114e-03
#     8.31759490e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 146
# [[  9.95977613e-01   6.12371964e-04   1.13151585e-03   1.47839670e-03
#     8.00102529e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 147
# [[  9.96130706e-01   5.89064944e-04   1.08845009e-03   1.42212858e-03
#     7.69650440e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 148
# [[  9.96277972e-01   5.66644995e-04   1.04702343e-03   1.36800203e-03
#     7.40357364e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 149
# [[  9.96419633e-01   5.45078354e-04   1.00717347e-03   1.31593555e-03
#     7.12179190e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 150
# [[  9.96555903e-01   5.24332544e-04   9.68840211e-04   1.26585074e-03
#     6.85073483e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 151
# [[  9.96686986e-01   5.04376325e-04   9.31965926e-04   1.21767216e-03
#     6.58999426e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 152
# [[  9.96813080e-01   4.85179644e-04   8.96495085e-04   1.17132728e-03
#     6.33917754e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 153
# [[  9.96934375e-01   4.66713593e-04   8.62374273e-04   1.12674629e-03
#     6.09790696e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 154
# [[  9.97051054e-01   4.48950365e-04   8.29552107e-04   1.08386206e-03
#     5.86581920e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 155
# [[  9.97163291e-01   4.31863209e-04   7.97979159e-04   1.04261002e-03
#     5.64256475e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 156
# [[  9.97271257e-01   4.15426394e-04   7.67607886e-04   1.00292804e-03
#     5.42780742e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 157
# [[  9.97375114e-01   3.99615169e-04   7.38392551e-04   9.64756360e-04
#     5.22122380e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 158
# [[  9.97475017e-01   3.84405722e-04   7.10289157e-04   9.28037508e-04
#     5.02250280e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 159
# [[  9.97571119e-01   3.69775150e-04   6.83255386e-04   8.92716183e-04
#     4.83134517e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 160
# [[  9.97663563e-01   3.55701422e-04   6.57250526e-04   8.58739196e-04
#     4.64746304e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 161
# [[  9.97752488e-01   3.42163342e-04   6.32235418e-04   8.26055382e-04
#     4.47057951e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 162
# [[  9.97838029e-01   3.29140526e-04   6.08172390e-04   7.94615521e-04
#     4.30042821e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 163
# [[  9.97920314e-01   3.16613360e-04   5.85025207e-04   7.64372269e-04
#     4.13675291e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 164
# [[  9.97999467e-01   3.04562982e-04   5.62759011e-04   7.35280081e-04
#     3.97930713e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 165
# [[  9.98075608e-01   2.92971244e-04   5.41340271e-04   7.07295150e-04
#     3.82785377e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 166
# [[  9.98148851e-01   2.81820690e-04   5.20736734e-04   6.80375331e-04
#     3.68216476e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 167
# [[  9.98219306e-01   2.71094528e-04   5.00917372e-04   6.54480087e-04
#     3.54202071e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 168
# [[  9.98287080e-01   2.60776607e-04   4.81852340e-04   6.29570422e-04
#     3.40721057e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 169
# [[  9.98352274e-01   2.50851388e-04   4.63512927e-04   6.05608824e-04
#     3.27753134e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 170
# [[  9.98414987e-01   2.41303926e-04   4.45871517e-04   5.82559211e-04
#     3.15278773e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 171
# [[  9.98475313e-01   2.32119842e-04   4.28901543e-04   5.60386871e-04
#     3.03279189e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 172
# [[  9.98533343e-01   2.23285307e-04   4.12577450e-04   5.39058416e-04
#     2.91736312e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 173
# [[  9.98589164e-01   2.14787016e-04   3.96874655e-04   5.18541726e-04
#     2.80632760e-04]]
#
# Probability rat in on Track A, B, C, D or E at time t + 174
# [[  9.98642861e-01   2.06612172e-04   3.81769513e-04   4.98805907e-04
#     2.69951812e-04]]

# %% [markdown]
# <strong><span style="color:red">Conclusion : </span>Since Track A is an absorbing state in the long run probability of the position of the rat irrespective of where it starts tends to be near 1 at Track A</strong>

# %% [markdown]
# ### Part 2 - Real-world example (20 points)
#
# Similar to the example of a rat moving between subway tracks, let's dig into an example of people moving throughout a subset of 5 Brooklyn Neighborhoods to understand Markov Processes.
# <br><br>
# Assumptions made here are that total population is static (i.e. no new entrants or people moving outside of this subset of neighborhoods), and that there's a 40% chance that people stay in their current neighborhood (which can be interpreted as either not moving or moving very close by) and a known probability of moving from one neighborhood to another (these are defined in the code below), with preference shown for bordering neighborhoods.
# <br><br>
# We will load geo-data and filter to the specified Brooklyn neighborhoods. We will then examine movement between neighborhoods as a Markov Process, iterating until an equilibrium becomes apparent (hint: you should not see any absorbing states in this example), then visualize and interpret the results.

# %% [markdown]
# **a)**: Go through the below example, completing the code where marked. In the end, your dataframe should look similar to the output. (15 points)

# %%
import imageio
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import time
from IPython.display import HTML

sns.set_style('white')
# filters to apply to the data
county = 'Kings'
hoods  = ['Downtown', 'DUMBO', 'Fort Greene', 'Boerum Hill', 'Clinton Hill']

def get_neighborhoods(file, county=county, neighborhoods=hoods):
    '''
    reads in geopandas file from Zillow, returns geodataframe with specified neighborhoods
    '''
    # read in the geodata file ('file') and consolidate to the 5 selected neighborhoods (listed above)
    ny_gdf = gpd.read_file(file)
    ny_gdf = ny_gdf.loc[(ny_gdf["Name"].isin(hoods)) & (ny_gdf["County"].isin([county])),:]
    
    # locate coordinate points to plot neighborhood names
    ny_gdf['coords'] = ny_gdf['geometry'].apply(lambda x: x.representative_point().coords[:])
    ny_gdf['coords'] = [coords[0] for coords in ny_gdf['coords']]
    return ny_gdf

bk_neighborhoods = get_neighborhoods('ZillowNeighborhoodsNY.shp')
bk_neighborhoods = bk_neighborhoods.sort_values('Name').reset_index(drop=True)
bk_neighborhoods
# Out:
#   State County      City          Name RegionID  \
# 0    NY  Kings  New York   Boerum Hill   272994
# 1    NY  Kings  New York  Clinton Hill   270815
# 2    NY  Kings  New York         DUMBO   270841
# 3    NY  Kings  New York      Downtown   270825
# 4    NY  Kings  New York   Fort Greene   273766
#
#                                             geometry  \
# 0  POLYGON ((-73.98682489707035 40.68846655576456...
# 1  POLYGON ((-73.9619257224787 40.69778778197278,...
# 2  POLYGON ((-73.98446723099994 40.70646091900005...
# 3  POLYGON ((-73.98697203810939 40.70105040762233...
# 4  POLYGON ((-73.98230754099966 40.70227250100029...
#
#                                      coords
# 0    (-73.9864896425407, 40.68600290969882)
# 1     (-73.96455445229091, 40.689058350724)
# 2  (-73.99003960915954, 40.703545669500045)
# 3  (-73.98678098579373, 40.693458468711725)
# 4   (-73.97573066517539, 40.69136863239475)

# %% [markdown]
# Above we can see the geodataframe. Now let's plot it:

# %%
bk_neighborhoods.plot(figsize=(8, 6), edgecolor='black', alpha=0.2)

for idx, row in bk_neighborhoods.iterrows():
    plt.annotate(s=row['Name'], xy=row['coords'], color='Black', horizontalalignment='center', size=10)

# %% [markdown]
# Here, we define the likelihoods of moving from one neighborhood to another.
# Use a Dirichlet Distrobution (convenient for generating samples that sum to 1.0) to obtain an initial starting population for the neighborhoods https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.random.dirichlet.html

# %%
np.random.seed(42)
data = np.random.dirichlet(np.ones(5),1) # use a dirichlet distribution to create a 1-by-5 matrix of values that sum to 1.0 
initial_vals = zip(list(bk_neighborhoods.Name), np.array(data)[0])

print('Initial allocations:')
print('--------------------')
for i, j in initial_vals:
    print('{:<13s} {:>5.2f}%'.format(i, round(j, 4)*100))
print('--------------------')
print()

move_likelihoods = np.matrix('0.4 0.1 0.1 0.2 0.2; 0.1 0.4 0.1 0.15 0.25; 0.1 0.1 0.4 0.2 0.2;' 
                             + '0.2 0.05 0.15 0.4 0.2; 0.15 0.2 0.05 0.2 0.4')
pd.DataFrame(data=move_likelihoods, index=bk_neighborhoods.Name, columns=bk_neighborhoods.Name) 
# we could use 'tabulate' here, as this is for visualization purposes, but a pd dataframe is 
# often just as clear and has more compatability with python environments
# Out:
# Initial allocations:
# --------------------
# Boerum Hill    7.98%
# Clinton Hill  51.20%
# DUMBO         22.40%
# Downtown      15.53%
# Fort Greene    2.89%
# --------------------
# Name          Boerum Hill  Clinton Hill  DUMBO  Downtown  Fort Greene
# Name
# Boerum Hill          0.40          0.10   0.10      0.20         0.20
# Clinton Hill         0.10          0.40   0.10      0.15         0.25
# DUMBO                0.10          0.10   0.40      0.20         0.20
# Downtown             0.20          0.05   0.15      0.40         0.20
# Fort Greene          0.15          0.20   0.05      0.20         0.40

# %% [markdown]
# Here we will build a Markov process and visualize it in a GIF; this is useful for seeing equilibrium state reached over time. We will then look at the numbers to confirm what the plot is showing us.

# %%
years = 7
pct_by_year = []

def plot_neighborhood_movement(years):

    pct_in_hood = data * np.linalg.matrix_power(move_likelihoods, years) # use the matrix_power function to run a step in the markov process
    bk_neighborhoods['pct_in_hood'] = np.array(pct_in_hood)[0]
    pct_by_year.append(np.array(pct_in_hood)[0])
    vmin, vmax = bk_neighborhoods['pct_in_hood'].min(), bk_neighborhoods['pct_in_hood'].max()

    fig, ax = plt.subplots(figsize=(8,6))
    base = bk_neighborhoods.plot(ax=ax, column='pct_in_hood', edgecolor='grey', 
                                cmap='Blues', vmin=vmin, vmax=vmax, legend=False)

    plt.title('Year:{}'.format(years), size=16)
    
    for idx, row in bk_neighborhoods.iterrows():
        plt.annotate(s=row['Name'], xy=row['coords'], color='Red', horizontalalignment='center', size=10) # put neighborhood names on the plot in red font

    fig.canvas.draw()
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    image = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    plt.close(fig)
    return image

kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('neighborhood_movement.gif', [plot_neighborhood_movement(year) for year in range(years)], fps=1)

HTML('<img src="neighborhood_movement.gif">')
# Out:
# <img src="neighborhood_movement.gif">

# %%
imageio.mimsave('neighborhood_movement_100.gif', [plot_neighborhood_movement(year) for year in range(100)], fps=1)

HTML('<img src="neighborhood_movement_100.gif">')
# Out:
# <img src="neighborhood_movement_100.gif">

# %% [markdown]
# **b)**: Interpret the results - what trends do we notice towards the end of the GIF? Why might this be? What would we expect if we ran this over 100 iterations (feel free to try this)? (5 points)

# %% [markdown]
# <strong><span style="color:red">Conclusion : </span>The system reaches an equilibrium state near the 6th iteration. This might be due to relatively higher move probabilities for Fort Greene, Downtown and Boerum Hill when compared to DUMBO and Clinton Hill. If we run this for 100 iterations we can see that the system will remain in equilibrium from the 6th iteration.</strong>

# %% [markdown]
# This is some pretty cool stuff! If you had enough data, you could theoretically do this for all of NYC (you'd additionally have to factor in people moving into and out of the city, but that's not too hard). Further, you might change the percentages over time (e.g. when the L-train shuts down, you may want to lower the % of people moving to Williamsburg in your model).

# %% [markdown]
# ## Problem 3 - Time Series (40 points)

# %% [markdown]
# This dataset looks at measurements of electric power consumption in one household with a one-minute sampling rate over a period of almost 4 years; the data is initially messy, and will take a lot of cleaning. You will find that there is some correlation between the data (i.e. what we know about the current state can tell us something about the future state), and you will then construct an Autoregressive Model to predict future values.
#
# Source: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
#
# Variable Descriptions:
# 1. date: Date in format dd/mm/yyyy <br>
# 2. time: time in format hh:mm:ss <br>
# 3. global_active_power: household global minute-averaged active power (in kilowatt) <br>
# 4. global_reactive_power: household global minute-averaged reactive power (in kilowatt) <br>

# %%
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AR

sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ### Part 1: Reading Data (15 points)
# Read in the data. It is in a .txt file, but you can read it in with 'pd.read_csv()' - you may want to consider the  'sep', 'parse_dates', 'usecols', 'infer_datetime_format', 'keep_default_na', 'skip_blank_lines', 'skiprows', and 'dtype' arguements in the function call.
# <br><br>
# You also may want to use the 'nrows' arguement or use a limited version of the dataset as you adjust these, as it is a large one.
# <br><br>
# Use the column names = ['Date', 'Global_active_power', 'Global_reactive_power']
# (15 points)

# %%
pwr_consumption = pd.read_csv('household_power_consumption.txt',sep=';',infer_datetime_format=True,keep_default_na=False,usecols=['Date', 'Global_active_power', 'Global_reactive_power'],)
pwr_consumption['Global_active_power'] = pd.to_numeric(pwr_consumption['Global_active_power'],errors='coerce')
pwr_consumption['Global_reactive_power'] = pd.to_numeric(pwr_consumption['Global_reactive_power'],errors='coerce')
pwr_consumption.dropna(inplace=True)
pwr_consumption = pwr_consumption.groupby("Date").sum().reset_index()# group the newly-cleaned data by date, using the .sum() function to aggregate
pwr_consumption['Date'] = pd.to_datetime(pwr_consumption['Date'])
pwr_consumption.sort_values("Date",inplace=True)
pwr_consumption.head()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Date  Global_active_power  Global_reactive_power
# 339 2006-12-16             1209.176                 34.922
# 387 2006-12-17             3390.460                226.006
# 435 2006-12-18             2203.826                161.792
# 482 2006-12-19             1666.194                150.942
# 576 2006-12-20             2225.748                160.998

# %% [markdown]
# ### Part 2: Visualizing Time-Series (10 points)
# Plot data for 'global_active_pwr' and 'global_reactive_pwr' on a time-series. In addition to a standard line plot, also generate a plot using lag_plot() function to examine the correlation. So, your output should have 4 plots. Describe your findings.
# <br><br>
# Make a function that takes 2 arguments (you may use additional) - a plotting function & data containing the 2 required columns (global_active_pwr, global_reactive_pwr) and then generates the plot specified.
# <br><br>
# Make sure the plots have a title and the axes are labelled. (10 points)

# %%
pwr_consumption.index = range(len(pwr_consumption))
glb_active_pwr   = pwr_consumption['Global_active_power']
glb_reactive_pwr = pwr_consumption['Global_reactive_power']

def plot_func(series,title):
    f,ax = plt.subplots()
    ax.plot(series.values)
    ax.set_title("Time Series for : " + title)
    
def lag_func(series,title):
    f,ax = plt.subplots()
    pd.plotting.lag_plot(series,ax=ax)
    ax.set_title("Lag Plot for : " + title)
    
def time_series_plotting(func, series1, series2, title):
    """
    takes plotting function, 2 time-series and additional arguments (if required)
    """
    
    func(series1,title)
    func(series2,title)
    
    plt.show()

time_series_plotting(plot_func, glb_active_pwr, glb_reactive_pwr,"glb_reactive_pwr")
time_series_plotting(lag_func, glb_active_pwr, glb_reactive_pwr,"glb_reactive_pwr")

# %% [markdown]
# <strong>There is no particular trend in the standard line plot. There is no stationarity either.</strong>

# %% [markdown]
# ### Part 3: Time-Series Forecasting using AR(1) (15 points)
# Fit an autoregressive model to the data, and use it to make predictions over the next 30 days of useage (defined by creating a test set from the last 30 days of available data).
# 1. Perform a train-test split on time-series data. Explain why random sampling isn't the best option for time-series.
# 2. Fit AR(1) model
# 3. Predict on test set
# 4. Calculate Root-Mean Squared Error (RMSE)
# $$ RMSE = \frac{1}{N} \sum_{i=0}^N \sqrt{ (\hat{y}_i - y_i)^2 } $$

# %%
from statsmodels.tsa.ar_model import AR
import numpy as np

# %%
def fit_AR1(series):
    """
    Takes in a Time-series, splits into train and test, fits AR(1) model, predicts on the test set, calculates error
    and return the predictions and the test set for visualization
    """
    # Perform a train-test split on the dataset keeping ~70% for the training set
    train, test = series[0:int(len(series)*0.7)],series[int(len(series)*0.7):]
    
    # Fit AR(1) model
    model = AR(train)
    model = model.fit()
    
    # Get the predictions in an array
    predictions = model.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False) 
    
    # Obtain and print Root-Mean Squared Error (RMSE)
    rmse_error = np.sqrt(((predictions - test) ** 2).mean())
    print(rmse_error)

    return test, predictions

t1, p1 = fit_AR1(glb_active_pwr)
t2, p2 = fit_AR1(glb_reactive_pwr)

fig, ax = plt.subplots(2, figsize=(16,6))

plt.subplot(121)
# Visualize actual values vs predicted values for 'Global Active Power'
plt.plot(t1,label="Actual")
plt.plot(p1,label="Predicted")
plt.title('Global Active Power')
plt.legend()

plt.subplot(122)
# Visualize actual values vs predicted values for 'Global Reactive Power'
plt.plot(t2,label="Actual")
plt.plot(p2,label="Predicted")
plt.title('Global Reactive Power')
plt.legend()

plt.show()
# Out:
# 504.871792568
# 49.8140123182

# %% [markdown]
# (Reasoning for train-test split here)
# <strong>The data was sorted according to length and then split in a 70-30 ratio on the sorted data. In time series analysis data needs to be sorted by date and test data should be future data.</strong>

# %% [markdown]
# (Describe your findings here)<strong> Both the models appear to reach an absorbing state after the first few iterations.</strong>
